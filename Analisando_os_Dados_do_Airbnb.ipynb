# %% [markdown]
# <a href="https://colab.research.google.com/github/vitoriamsj/portfolio_data_science/blob/main/Analisando_os_Dados_do_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise dos Dados do Airbnb - *Rio de Janeiro*
#
# O [Airbnb](https://www.airbnb.com.br/) já é considerado como sendo a **maior empresa hoteleira da atualidade**. Ah, o detalhe é que ele **não possui nenhum hotel**!
#
# Conectando pessoas que querem viajar (e se hospedar) com anfitriões que querem alugar seus imóveis de maneira prática, o Airbnb fornece uma plataforma inovadora para tornar essa hospedagem alternativa.
#
# No final de 2018, a Startup fundada 10 anos atrás, já havia **hospedado mais de 300 milhões** de pessoas ao redor de todo o mundo, desafiando as redes hoteleiras tradicionais.
#
# Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal [Inside Airbnb](http://insideairbnb.com/get-the-data.html), é possível baixar uma grande quantidade de dados para desenvolver projetos e soluções de *Data Science*.
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
# **Neste *notebook*, iremos analisar os dados referentes à cidade do Rio de Janeiro, e ver quais insights podem ser extraídos a partir de dados brutos.**

# %% [markdown]
# ## Obtenção dos Dados

# %%
# importar os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv("http://data.insideairbnb.com/brazil/rj/rio-de-janeiro/2020-04-20/visualisations/listings.csv")

# %% [markdown]
# ## Análise dos Dados

# %% [markdown]
# **Dicionário das variáveis**
#
# * `id` - número de id gerado para identificar o imóvel
# * `name` - nome da propriedade anunciada
# * `host_id` - número de id do proprietário (anfitrião) da propriedade
# * `host_name` - Nome do anfitrião
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido
# * `neighbourhood` - nome do bairro
# * `latitude` - coordenada da latitude da propriedade
# * `longitude` - coordenada da longitude da propriedade
# * `room_type` - informa o tipo de quarto que é oferecido
# * `price` - preço para alugar o imóvel
# * `minimum_nights` - quantidade mínima de noites para reservar
# * `number_of_reviews` - número de reviews que a propriedade possui
# * `last_review` - data do último review
# * `reviews_per_month` - quantidade de reviews por mês
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias
#
# Antes de iniciar qualquer análise, vamos verificar a cara do nosso *dataset*, analisando as 5 primeiras entradas.

# %%
# mostrar as 5 primeiras entradas
df.head()
# Out:
#       id  ... availability_365
# 0  17878  ...                0
# 1  21280  ...               69
# 2  25026  ...               95
# 3  31560  ...                0
# 4  35636  ...              358
#
# [5 rows x 16 columns]

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**

# %% [markdown]
# Importante identificar quantas linhas e colunas nosso DataFrame possui.

# %%
# identificar o volume de dados do DataFrame
print("Entradas (Linhas):\t {}".format(df.shape[0]))
print("Variáveis(Colunas):\t {}\n".format(df.shape[1]))

#identificar os tipos das variáveis
display(df.dtypes)
# Out:
# Entradas (Linhas):	 35870
# Variáveis(Colunas):	 16
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ### **Q2. Qual a porcentagem de valores ausentes no *dataset*?**

# %% [markdown]
# A primeira coisa que você tem que saber quando lida com um conjunto de dados novos, é a quantidade e proporção dos missing values. Portanto, vamos identificá-los abaixo:

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
print ('Porcentagem (%) de valores faltantes') 
((df.isnull().sum() / df.shape[0]).sort_values(ascending=False))*100
# Out:
# Porcentagem (%) de valores faltantes
# neighbourhood_group               100.000000
# reviews_per_month                  41.165319
# last_review                        41.165319
# name                                0.161695
# host_name                           0.013939
# availability_365                    0.000000
# calculated_host_listings_count      0.000000
# number_of_reviews                   0.000000
# minimum_nights                      0.000000
# price                               0.000000
# room_type                           0.000000
# longitude                           0.000000
# latitude                            0.000000
# neighbourhood                       0.000000
# host_id                             0.000000
# id                                  0.000000
# dtype: float64

# %% [markdown]
# Podemos observar que a coluna Neighbourhood_group possui 100% de valores vazios.
# Reviews_per_month possui 41%, assim como a coluna last_review.
# As variáveis name e host_name tem aproximadamente 0,1% dos valores nulos.

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**

# %% [markdown]
# Também conhecido como diagrama de dispersão de frequências, um histograma consiste em uma representação gráfica de dados que são divididos em classes. Assim, esta representação gráfica é feita com o objetivo de conferir como um processo se comporta em relação a suas especificidades.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins=15, edgecolor='black', figsize=(15,10));

# %% [markdown]
# Os outliers são dados que se diferenciam drasticamente de todos os outros, são pontos fora da curva normal. Em outras palavras, um outlier é um valor que foge da normalidade e que pode (e provavelmente irá) causar anomalias nos resultados obtidos por meio de algoritmos e sistemas de análise.
#
# Olhe por exemplo as variáveis price, minimum_nights e calculated_host_listings_count.
#
# Os valores não seguem um padrão, e distorcem toda a representação gráfica.
#
# Portanto, abaixo iremos **analisar** o DataFrame:

# %%
# ver o resumo estatístico das variáveis numéricas
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe()
# Out:
#                price  ...  availability_365
# count   35870.000000  ...      35870.000000
# mean      753.686367  ...        180.371815
# std      2229.366334  ...        152.510778
# min         0.000000  ...          0.000000
# 25%       158.000000  ...          0.000000
# 50%       298.000000  ...        178.000000
# 75%       632.000000  ...        363.000000
# max    131727.000000  ...        365.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# * A variável price possui 75% do valor abaixo de 632, porém seu valor máximo é 131727.
# * A quantidade mínima de noites (minimum_nights) está acima de 365 dias no ano.
# * Analisando a coluna calculated_host_listings_count no histograma, conseguimos ver que existem poucas acomodações no geral (0-50), porém existem valores no gráfico com cerca de 200 acomodações (isso é um outlier).

# %% [markdown]
# Após identificar os outliers, podemos **limpar** o dataframe.

# %%
# remover os *outliers* em um novo DataFrame
df_clean = df.copy()
df_clean.drop(df_clean[df_clean.price > 1500].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > 30].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.calculated_host_listings_count > 50].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.number_of_reviews > 200].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.reviews_per_month > 6].index, axis=0, inplace=True)

# remover `neighbourhood_group`, pois está totalmente vazio
df_clean.drop('neighbourhood_group', axis=1, inplace=True)

# plotar o histograma para as variáveis numéricas
df_clean.hist(bins=15, edgecolor = 'black', figsize=(15,10));

# %% [markdown]
# ### **Q4. Qual a média dos preços de aluguel?**

# %% [markdown]
# Através da fórmula mean podemos identificar o valor médio dos aluguéis no Rio de Janeiro.

# %%
# ver a média da coluna `price``
df_clean.price.mean()
# Out:
# 370.8413295904045

# %% [markdown]
# ### **Q4. Qual a correlação existente entre as variáveis**

# %% [markdown]
# A correlação é um conceito estatístico que visa compreender a relação que existe entre duas variáveis.

# %%
# criar uma matriz de correlação

corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()

# mostrar a matriz de correlação
display(corr)
# Out:
#                                    price  ...  availability_365
# price                           1.000000  ...         -0.020225
# minimum_nights                  0.166722  ...         -0.012737
# number_of_reviews              -0.171696  ...          0.048808
# reviews_per_month              -0.163143  ...         -0.025685
# calculated_host_listings_count -0.027862  ...          0.108960
# availability_365               -0.020225  ...          1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# O heatmap é um gráfico muito útil para identificar padrões, principalmente quando temos muitas variáveis no gráfico, onde as cores de cada correlação vão indicar a força e o sinal da correlação.
# Abaixo conseguimos analisar esse tipo de gráfico:

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True,linecolor='white', annot=True);

# %% [markdown]
# ### **Q5. Qual o tipo de imóvel mais alugado no Airbnb?**

# %% [markdown]
# A coluna da variável room_type indica o tipo de locação que está anunciada no Airbnb. Se você já alugou no site, sabe que existem opções de apartamentos/casas inteiras, apenas o aluguel de um quarto ou mesmo dividir o quarto com outras pessoas.
#
# Vamos contar a quantidade de ocorrências de cada tipo de aluguel, usando o método `value_counts()`.

# %%
# mostrar a quantidade de cada tipo de imóvel disponível

df_clean.room_type.value_counts()
# Out:
# Entire home/apt    21527
# Private room        8904
# Shared room          765
# Hotel room           152
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
print ('Porcentagem (%) de cada tipo de imóvel disponível')
(df_clean.room_type.value_counts() / df_clean.shape[0]) * 100
# Out:
# Porcentagem (%) de cada tipo de imóvel disponível
# Entire home/apt    68.671048
# Private room       28.403726
# Shared room         2.440347
# Hotel room          0.484879
# Name: room_type, dtype: float64

# %% [markdown]
# ### **Q6. Qual a localidade mais cara do dataset?**

# %% [markdown]
# Uma maneira de se verificar uma variável em função da outra é usando `groupby()`. No caso, queremos comparar os bairros (*neighbourhoods*) a partir do preço de locação.

# %%
# ver preços por bairros, na média

expensive_neighbourhood = df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
expensive_neighbourhood
# Out:
# neighbourhood
# Vaz Lobo                  875.666667
# Engenheiro Leal           800.000000
# Ricardo de Albuquerque    601.200000
# Paciência                 523.555556
# Lagoa                     517.619195
# Abolição                  483.666667
# Leblon                    479.253846
# Anchieta                  475.600000
# Deodoro                   474.000000
# Joá                       472.382979
# Name: price, dtype: float64

# %% [markdown]
# Acima, vemos que bairros como Vaz Lobo, Engenheiro Albuquerque, Ricardo de Albuquerque e Paciência, estão com média de preço superior a de lugares como Leblon, Barra da Tijuca e Lagoa.
#
# Uma pessoa que não conhecesse o Rio poderia apresentar esses resultados sem se questionar.
#
# Para verificar isso melhor, vamos ver a quantidade de acomodações por localização.

# %%
expensive_list = expensive_neighbourhood.keys().to_list()
df_clean['neighbourhood'].loc[df_clean['neighbourhood'].isin(expensive_list)].value_counts().sort_values(ascending=False)
# Out:
# Leblon                    1300
# Lagoa                      323
# Joá                         47
# Paciência                    9
# Abolição                     6
# Ricardo de Albuquerque       5
# Anchieta                     5
# Vaz Lobo                     3
# Engenheiro Leal              2
# Deodoro                      2
# Name: neighbourhood, dtype: int64

# %% [markdown]
# Agora podemos perceber que alguns bairros possuem poucas acomodações, por isso a média causou uma impressão errada. Com certeza as três acomodações de Vaz Lobo não representam o bairro inteiro.
# Portanto, vamos remover as localidades com menos de 10 acomodações e tirar uma média mais correta.

# %%
neighbourhood_clean = df_clean['neighbourhood'].map(df_clean['neighbourhood'].value_counts() > 10)
neigh_df_filtered = df_clean[neighbourhood_clean]

neighbourhood_by_mean = neigh_df_filtered.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
neighbourhood_by_mean
# Out:
# neighbourhood
# Lagoa                       517.619195
# Leblon                      479.253846
# Joá                         472.382979
# Barra da Tijuca             471.211702
# Engenho de Dentro           470.861111
# Jacarepaguá                 465.541573
# Maracanã                    461.579767
# Recreio dos Bandeirantes    454.865804
# São Conrado                 451.744318
# Vargem Grande               449.336449
# Name: price, dtype: float64

# %% [markdown]
# Agora sim possuímos uma visão mais correta sobre as 10 localidades mais caras.
#
# Vamos usar a latitude e longitude para verificar como está a distribuição das acomodações.

# %%
# plotar os imóveis pela latitude-longitude
df_clean.plot(kind='scatter', x='longitude', y='latitude', title='Dispersão');

# %% [markdown]
# Podemos também verificar a dispersão das acomodações e analisar pela faixa de preço.

# %%
# plotar os imóveis pela latitude-longitude
df_clean.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4, c=df_clean['price'], s=8, cmap=plt.get_cmap('jet'), figsize=(12,8), title = 'Dispersão analisada pela Faixa de Preço');

# %% [markdown]
# ### **Q7. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %% [markdown]
# As pessoas costumam alugar imóveis por pelo menos 3 dias.

# %%
# ver a média da coluna `minimum_nights``

df_clean.minimum_nights.mean()
# Out:
# 3.4710029347964784

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Foi feita apenas uma análise superficial na base de dados do Airbnb, porém já se percebeu que existem outliers (valores que fogem da normalidade) em algumas das variáveis.
#
# Também se notou que em algumas localidades há poucos imóveis disponíveis, o que pode distorcer as informações estatísticas de alguns atributos.
#
# Por fim, lembra-se que este dataset é uma versão resumida, ideal apenas para uma abordagem inicial.
